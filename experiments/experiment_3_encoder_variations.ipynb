# %%
from octis.dataset.dataset import Dataset
import hdbscan
import sys
sys.path.append('C:\\Users\\Martin\\Documents\\GitHub\\master\\evaluation')
import trainer
import helper
import pandas as pd

# %%
from sentence_transformers import SentenceTransformer

# %%
import multimodal
import c_tf_idf
import multimodalModel

# %%
output_folder = './results/experiment_3'
dataset_folder = './multimodal_custom_octis_dataset/'

# %%
mm_dataset = Dataset()
mm_dataset.load_custom_dataset_from_folder(dataset_folder)

# %%
image_embedding_model = SentenceTransformer("clip-ViT-B-32")
# Out:
# c:\Users\Martin\AppData\Local\Programs\Python\Python38\lib\site-packages\torchvision\transforms\transforms.py:332: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
text_embedding_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
path_to_data = './multimodal_data.tsv'

try:
    texts, images = multimodal.get_image_and_text_from_file(path_to_data)
except FileNotFoundError:
    base_path = '..\\data\\processed'
    ends = ['processed_part-00000-48a6f07e-bb86-4735-aac7-883349f41a28-c000.tsv'
            ,'processed_part-00001-48a6f07e-bb86-4735-aac7-883349f41a28-c000.tsv'
            ,'processed_part-00002-48a6f07e-bb86-4735-aac7-883349f41a28-c000.tsv'
            ,'processed_part-00003-48a6f07e-bb86-4735-aac7-883349f41a28-c000.tsv'
            ,'processed_part-00004-48a6f07e-bb86-4735-aac7-883349f41a28-c000.tsv'
            ,]
    paths = [f'{base_path}\\{end}' for end in ends]
    df = helper.load_all_data(paths)
    df.to_csv(path_to_data, index=False, sep='\t')
    texts, images = helper.get_image_and_text_from_df(df)

# %%
text_embed = multimodal.get_embeddings_from_text(texts, text_embedding_model)
image_embed = multimodal.get_embeddings_from_images(images, image_embedding_model)
# Out:
# 100%|██████████| 91/91 [00:22<00:00,  4.10it/s]
#  37%|███▋      | 34/91 [00:28<00:45,  1.27it/s]c:\Users\Martin\AppData\Local\Programs\Python\Python38\lib\site-packages\PIL\Image.py:945: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 100%|██████████| 91/91 [01:14<00:00,  1.23it/s]

# %%
metricsloader = trainer.MetricsLoader(dataset_folder)

# %%
params = {'path_to_data':path_to_data,
'embedding_model':image_embedding_model, # not used

'precomputed_text_embeds':text_embed,
'precomputed_image_embeds':image_embed
}
base_name = 'experiment_3_diff_embeds'

min_cluster_size = 200
clusterer = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size)
params['clusterer']=clusterer

get_extra_info = True
fitted_clusterers = []
image_representatives = []
top_terms_representatives = []
mm_trainer = trainer.Trainer(custom_dataset_folder=dataset_folder, params=params, metrics_loader=metricsloader)
helper.run_experiment(mm_trainer, output_folder, name=f'{base_name}unrestricted_topics_min_cluster_size_{min_cluster_size}', num_times=10)
if get_extra_info:
    last_fit_clusterer = mm_trainer.model.clusterer
    fitted_clusterers.append(last_fit_clusterer)

    mm_trainer.model.find_image_representatives()
    last_fit_images = mm_trainer.model.cluster_images
    last_fit_terms = mm_trainer.model.top_terms

    image_representatives.append(last_fit_images)
    top_terms_representatives.append(last_fit_terms)
# Out:
# start:28032023_12_18_31
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Martin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 100%|██████████| 48919/48919 [00:33<00:00, 1449.51it/s]
# 100%|██████████| 48919/48919 [00:15<00:00, 3069.28it/s]
# 100%|██████████| 48919/48919 [02:14<00:00, 364.55it/s]
# 100%|██████████| 48919/48919 [00:09<00:00, 4922.01it/s]
# 100%|██████████| 48919/48919 [01:29<00:00, 546.17it/s]
# 100%|██████████| 48919/48919 [00:15<00:00, 3234.30it/s]
# 100%|██████████| 48919/48919 [00:09<00:00, 5418.59it/s]
# 100%|██████████| 48919/48919 [00:31<00:00, 1546.12it/s]
# 100%|██████████| 48919/48919 [00:00<00:00, 227498.79it/s]
# diversity:0.8285714285714286
# wetc:0.684313644006951
# end:28032023_13_20_33

# %%
#for fc in fitted_clusterers:
#    fc.condensed_tree_.plot(select_clusters=True)

# %%
import ipyplot
for nr in range(len(image_representatives)):
    ipyplot.plot_images([*image_representatives[nr].values()],custom_texts=top_terms_representatives[nr], max_images=20, img_width=150)
# Out:
# c:\Users\Martin\AppData\Local\Programs\Python\Python38\lib\site-packages\ipyplot\_utils.py:95: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   return np.asarray(seq, dtype=type(seq[0]))
#     <style>
#         #ipyplot-html-viewer-toggle-JUe5nNKzSCCjgNeEeht5UF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JUe5nNKzSCCjgNeEeht5UF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JUe5nNKzSCCjgNeEeht5UF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JUe5nNKzSCCjgNeEeht5UF:checked ~ #ipyplot-html-viewer-textarea-JUe5nNKzSCCjgNeEeht5UF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JUe5nNKzSCCjgNeEeht5UF:checked + #ipyplot-html-viewer-label-JUe5nNKzSCCjgNeEeht5UF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-JUe5nNKzSCCjgNeEeht5UF">
#         <label id="ipyplot-html-viewer-label-JUe5nNKzSCCjgNeEeht5UF" for="ipyplot-html-viewer-toggle-JUe5nNKzSCCjgNeEeht5UF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-JUe5nNKzSCCjgNeEeht5UF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-3oLWV2CvkgmKpCthM4C872 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3oLWV2CvkgmKpCthM4C872]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3oLWV2CvkgmKpCthM4C872]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3oLWV2CvkgmKpCthM4C872]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3oLWV2CvkgmKpCthM4C872">
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-bgJKVJPGAxNoDYkdE7yX5f" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['district' 'state' 'town' 'municipality' 'county' 'census' 'city'
#  'township' 'united' 'states' 'area' 'population']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-bgJKVJPGAxNoDYkdE7yX5f">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-CZ5qehAhJkmd6vxZo5aPyi" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['force' 'uss' 'first' 'air' 'aircraft' 'world' 'states' 'ship' 'built'
#  'united' 'navy' 'war']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-CZ5qehAhJkmd6vxZo5aPyi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-7T6aCCNJG4wVHN9SCnsj8h" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['area' 'south' 'district' 'railway' 'county' 'station' 'historic'
#  'located' 'building' 'city' 'town' 'river']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-7T6aCCNJG4wVHN9SCnsj8h">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PThhR2jpkPPF52ZjXjVMBB" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['football' 'world' 'hockey' 'basketball' 'national' 'league' 'played'
#  'footballer' 'player' 'professional' 'team' 'plays']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PThhR2jpkPPF52ZjXjVMBB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-Dfcch5ab5ukpe5upyYvZhM" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['one' 'actor' 'politician' 'member' 'band' 'served' 'best' 'first' 'film'
#  'also' 'known' 'american']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-Dfcch5ab5ukpe5upyYvZhM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PjJtEQ7dkNSevKJWW4MsoH" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['region' 'located' 'czech' 'town' 'th' 'force' 'republic' 'population'
#  'air' 'army' 'district' 'municipality']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#         <style>
#         #ipyplot-imgs-container-div-3oLWV2CvkgmKpCthM4C872 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3oLWV2CvkgmKpCthM4C872 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3oLWV2CvkgmKpCthM4C872]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3oLWV2CvkgmKpCthM4C872]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3oLWV2CvkgmKpCthM4C872]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3oLWV2CvkgmKpCthM4C872">
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-bgJKVJPGAxNoDYkdE7yX5f" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['district' 'state' 'town' 'municipality' 'county' 'census' 'city'
#  'township' 'united' 'states' 'area' 'population']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-bgJKVJPGAxNoDYkdE7yX5f">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-CZ5qehAhJkmd6vxZo5aPyi" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['force' 'uss' 'first' 'air' 'aircraft' 'world' 'states' 'ship' 'built'
#  'united' 'navy' 'war']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-CZ5qehAhJkmd6vxZo5aPyi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-7T6aCCNJG4wVHN9SCnsj8h" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['area' 'south' 'district' 'railway' 'county' 'station' 'historic'
#  'located' 'building' 'city' 'town' 'river']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-7T6aCCNJG4wVHN9SCnsj8h">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PThhR2jpkPPF52ZjXjVMBB" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['football' 'world' 'hockey' 'basketball' 'national' 'league' 'played'
#  'footballer' 'player' 'professional' 'team' 'plays']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PThhR2jpkPPF52ZjXjVMBB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-Dfcch5ab5ukpe5upyYvZhM" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['one' 'actor' 'politician' 'member' 'band' 'served' 'best' 'first' 'film'
#  'also' 'known' 'american']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-Dfcch5ab5ukpe5upyYvZhM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PjJtEQ7dkNSevKJWW4MsoH" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['region' 'located' 'czech' 'town' 'th' 'force' 'republic' 'population'
#  'air' 'army' 'district' 'municipality']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-PjJtEQ7dkNSevKJWW4MsoH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3oLWV2CvkgmKpCthM4C872">
#         <div id="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-epxV5RRxhZgQ65vpNpLUMF" class="ipyplot-content-div-3oLWV2CvkgmKpCthM4C872">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">['also' 'common' 'described' 'america' 'extinct' 'genus' 'fish' 'family'
#  'species' 'known' 'found' 'sea']</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3oLWV2CvkgmKpCthM4C872-epxV5RRxhZgQ65vpNpLUMF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
